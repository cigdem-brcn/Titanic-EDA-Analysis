# %%
import pandas as pd
df = pd.read_csv('titanic/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.shape   #size
# Out:
# (891, 12)

# %%
df.Name.head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: str

# %%
df.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.iloc[:,3]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: str

# %%
df.loc[:, ['Name', 'Sex']]
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %%
df.set_index('Embarked')
# Out:
#           PassengerId  Survived  Pclass  \
# Embarked
# S                   1         0       3
# C                   2         1       1
# S                   3         1       3
# S                   4         1       1
# S                   5         0       3
# ...               ...       ...     ...
# S                 887         0       2
# S                 888         1       1
# S                 889         0       3
# C                 890         1       1
# Q                 891         0       3
#
#                                                        Name     Sex   Age  \
# Embarked
# S                                   Braund, Mr. Owen Harris    male  22.0
# C         Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# S                                    Heikkinen, Miss. Laina  female  26.0
# S              Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# S                                  Allen, Mr. William Henry    male  35.0
# ...

# %%
df.loc[(df.Sex == 'male') | (df.Sex == 'female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[df.Sex.isin(['male', 'female'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Pclass.sum()
# Out:
# np.int64(2057)

# %%
df.Age.mean()
# Out:
# np.float64(29.69911764705882)

# %%
df.Embarked.unique()
# Out:
# <StringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str

# %%
df.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df.loc[df.Cabin.notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df.Sex.describe()
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: Sex, dtype: object

# %%
df_Age_mean = df.Age.mean()
df.Age.map(lambda p:p-df_Age_mean)
# Out:
# 0      -7.699118
# 1       8.300882
# 2      -3.699118
# 3       5.300882
# 4       5.300882
#          ...
# 886    -2.699118
# 887   -10.699118
# 888          NaN
# 889    -3.699118
# 890     2.300882
# Name: Age, Length: 891, dtype: float64

# %%
def funct(value):
    value.Age=value.Age-df_Age_mean
    return value
df.apply(funct, axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  -7.699118
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   8.300882
# 2                               Heikkinen, Miss. Laina  female  -3.699118
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   5.300882
# 4                             Allen, Mr. William Henry    male   5.300882
# ..                                                 ...     ...        ...
# ...

# %%
df.Name + "-" + df.Sex
# Out:
# 0                           Braund, Mr. Owen Harris-male
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                          Heikkinen, Miss. Laina-female
# 3      Futrelle, Mrs. Jacques Heath (Lily May Peel)-f...
# 4                          Allen, Mr. William Henry-male
#                              ...
# 886                           Montvila, Rev. Juozas-male
# 887                  Graham, Miss. Margaret Edith-female
# 888      Johnston, Miss. Catherine Helen "Carrie"-female
# 889                           Behr, Mr. Karl Howell-male
# 890                             Dooley, Mr. Patrick-male
# Length: 891, dtype: str

# %%
df.groupby('Sex').Sex.count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
df.groupby('Sex').Age.min()
# Out:
# Sex
# female    0.75
# male      0.42
# Name: Age, dtype: float64

# %%
df.groupby('Age').apply(lambda df : df.Name.iloc[0])
# Out:
# Age
# 0.42          Thomas, Master. Assad Alexander
# 0.67                Hamalainen, Master. Viljo
# 0.75            Baclini, Miss. Helene Barbara
# 0.83            Caldwell, Master. Alden Gates
# 0.92           Allison, Master. Hudson Trevor
#                          ...
# 70.00             Mitchell, Mr. Henry Michael
# 70.50                    Connors, Mr. Patrick
# 71.00               Goldschmidt, Mr. George B
# 74.00                     Svensson, Mr. Johan
# 80.00    Barkworth, Mr. Algernon Henry Wilson
# Length: 88, dtype: str

# %%
df.groupby('Embarked').Age.agg([len,min,max])
# Out:
#           len   min   max
# Embarked
# C         168  0.42  71.0
# Q          77   NaN   NaN
# S         644  0.67  80.0

# %%
df.sort_values(by='Age', ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values(by=['Age', 'PassengerId'])
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 644          645         1       3                    Baclini, Miss. Eugenie
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.Age.dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df[pd.isnull(df.Cabin)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df.Cabin = df.Cabin.fillna("Unknow")   #update
df.Cabin
# Out:
# 0      Unknow
# 1         C85
# 2      Unknow
# 3        C123
# 4      Unknow
#         ...
# 886    Unknow
# 887       B42
# 888    Unknow
# 889      C148
# 890    Unknow
# Name: Cabin, Length: 891, dtype: str

# %%
df.Cabin = df.Cabin.replace("NaN" , "Unknow")    #update
df.Cabin
# Out:
# 0      Unknow
# 1         C85
# 2      Unknow
# 3        C123
# 4      Unknow
#         ...
# 886    Unknow
# 887       B42
# 888    Unknow
# 889      C148
# 890    Unknow
# Name: Cabin, Length: 891, dtype: str

# %%
df = df.rename(columns = {"Name" : "Ad"})    #update
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Ad     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.rename(index = {0:'first', 1:'second'})     #update
df
# Out:
#         PassengerId  Survived  Pclass  \
# first             1         0       3
# second            2         1       1
# 2                 3         1       3
# 3                 4         1       1
# 4                 5         0       3
# ...             ...       ...     ...
# 886             887         0       2
# 887             888         1       1
# 888             889         0       3
# 889             890         1       1
# 890             891         0       3
#
#                                                        Ad     Sex   Age  \
# first                             Braund, Mr. Owen Harris    male  22.0
# second  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                  Heikkinen, Miss. Laina  female  26.0
# 3            Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                                Allen, Mr. William Henry    male  35.0
# ...

# %%
pd.read_csv('titanic/test.csv')
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df1=pd.read_csv('titanic/train.csv')
df2=pd.read_csv('titanic/test.csv')
pd.concat([df1, df2])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
left = df1.set_index(['Age'])
right = df2.set_index(['Age'])
left.join(right, lsuffix='_1', rsuffix='_2')
# Out:
#       PassengerId_1  Survived  Pclass_1                   Name_1 Sex_1  \
# Age
# 22.0              1         0         3  Braund, Mr. Owen Harris  male
# 22.0              1         0         3  Braund, Mr. Owen Harris  male
# 22.0              1         0         3  Braund, Mr. Owen Harris  male
# 22.0              1         0         3  Braund, Mr. Owen Harris  male
# 22.0              1         0         3  Braund, Mr. Owen Harris  male
# ...             ...       ...       ...                      ...   ...
# 32.0            891         0         3      Dooley, Mr. Patrick  male
# 32.0            891         0         3      Dooley, Mr. Patrick  male
# 32.0            891         0         3      Dooley, Mr. Patrick  male
# 32.0            891         0         3      Dooley, Mr. Patrick  male
# 32.0            891         0         3      Dooley, Mr. Patrick  male
#
#       SibSp_1  Parch_1   Ticket_1  Fare_1 Cabin_1  ... PassengerId_2  \
# ...

# %%
df.groupby('Sex')['Survived'].mean().plot.bar(color=['steelblue', 'salmon'])
# Out:
# <Axes: xlabel='Sex'>
